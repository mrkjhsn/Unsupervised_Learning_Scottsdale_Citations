# %% [markdown]
# # CITATION LOCATION - clustering analysis using beat number for location
# Holding other variables constant and only examining for location, am I able to find areas of the city with specific types of clustering?

# %% [markdown]
# ### IMPORT LIBRARIES AND DATA

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import datetime
import glob
pd.set_option('display.max_columns', None)
sns.set(style='darkgrid')
# plt.style.use('bmh')
plt.rcParams['patch.edgecolor'] = 'none'
import jenkspy
# from yellowbrick.cluster import SilhouetteVisualizer


from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
# read in data that has already been preprocessed
df = pd.read_csv('data/clustering_features.csv')

# %%
df.shape
# Out:
# (36626, 10)

# %%
df.head()
# Out:
#    beat  cited_person_age  citation_time                charge_description  \
# 0  12.0              19.0            747  Speed Greater Than R&P or Posted
# 1  12.0              36.0            800  Speed Greater Than R&P or Posted
# 2   7.0              61.0            853  Speed Greater Than R&P or Posted
# 3   7.0              59.0            843  Speed Greater Than R&P or Posted
# 4  19.0              23.0           2215  Speed Greater Than R&P or Posted
#
#            street  month  day_of_week  hour_of_day               place_id  \
# 0       E Shea Bl      7            2            7       E Shea Bl - 6xxx
# 1       E Shea Bl      7            2            8       E Shea Bl - 6xxx
# 2  N Goldwater Bl      7            2            8  N Goldwater Bl - 4xxx
# 3  N Goldwater Bl      7            3            8  N Goldwater Bl - 4xxx
# 4       N Pima Rd      7            5           22       N Pima Rd - 2xxx
#
#        age_breaks
# 0  (17.999, 24.0]
# 1    (30.0, 39.0]
# 2    (51.0, 97.0]
# 3    (51.0, 97.0]
# 4  (17.999, 24.0]

# %%
# drop place id for the time being
df.drop(['place_id'], axis=1, inplace=True)

# %%
# drop features I don't want to use for now

df.drop(['citation_time'], axis=1, inplace=True)
# df.drop(['age_breaks'], axis=1, inplace=True)
# df.drop(['beat'], axis=1, inplace=True)
df.drop(['age_breaks'], axis=1, inplace=True)

# %%
df.drop(['street'], axis=1, inplace=True)

# %%
# drop citations where beat is null
# otherwise this creates problems for modeling

df.drop(df[df.beat.isnull()].index, inplace=True)

# %%
# verify no null values remain
df.isnull().sum()
# Out:
# beat                  0
# cited_person_age      0
# charge_description    0
# month                 0
# day_of_week           0
# hour_of_day           0
# dtype: int64

# %%
df.head()
# Out:
#    beat  cited_person_age                charge_description  month  \
# 0  12.0              19.0  Speed Greater Than R&P or Posted      7
# 1  12.0              36.0  Speed Greater Than R&P or Posted      7
# 2   7.0              61.0  Speed Greater Than R&P or Posted      7
# 3   7.0              59.0  Speed Greater Than R&P or Posted      7
# 4  19.0              23.0  Speed Greater Than R&P or Posted      7
#
#    day_of_week  hour_of_day
# 0            2            7
# 1            2            8
# 2            2            8
# 3            3            8
# 4            5           22

# %%
# identify unique beat locations
df.hour_of_day.unique()
# Out:
# array([ 7,  8, 22, 23, 19, 10,  0, 20, 12, 14, 15, 17, 11, 16,  5, 18, 21,
#         3,  6,  2,  9,  1, 13,  4], dtype=int64)

# %%
# which beats seem to be the most clustered?
sil_score = []
cluster_count = []

for hour in list(df.hour_of_day.unique()):
    
    df2 = df[df.hour_of_day == hour]
    X = pd.get_dummies(df2.drop(['hour_of_day'], axis=1))
    
    scaler = StandardScaler()
    X_std = scaler.fit_transform(X)
    
    # Defining the agglomerative clustering
    dbscan_cluster = DBSCAN(eps=.7, min_samples=20)

    # Fit model
    clusters = dbscan_cluster.fit_predict(X_std)
    
    # capture cluster count
    cluster_count.append(len(set(clusters)) - (1 if -1 in clusters else 0))

    # capture model fit
    if pd.Series(clusters).nunique() > 1:
        sil_score.append(round(metrics.silhouette_score(X_std, clusters, metric='euclidean'), 3))
    else:
        sil_score.append(np.nan)

# %% [markdown]
# ### Which beats seem the most clustered?

# %%
cluster_scores = pd.DataFrame(list(zip(list(df.beat.unique()), sil_score, cluster_count)),
             columns=['hour', 'sil_score', 'cluster_count']) \
        .set_index('hour') \
        .sort_values(by=['sil_score', 'cluster_count'], ascending=False)

cluster_scores
# Out:
#       sil_score  cluster_count
# hour
# 7.0       0.200              1
# 2.0       0.126              1
# 9.0       0.001              2
# 8.0      -0.068              1
# 5.0      -0.103              1
# 10.0     -0.104              4
# 11.0     -0.106              4
# 12.0     -0.124              3
# 1.0      -0.135              1
# 19.0     -0.136              4
# 4.0      -0.166              1
# 14.0     -0.193              4
# 20.0     -0.198              2
# 15.0     -0.233              7
# 3.0      -0.253              2
# 6.0         NaN              0
# 18.0        NaN              0
# 16.0        NaN              0
# 17.0        NaN              0
# 13.0        NaN              0
# 99.0        NaN              0

# %%
# plot silhouette score and cluster count
fig, (ax0, ax1) = plt.subplots(nrows=2,ncols=1, sharex=True, figsize=(10, 6))

cluster_scores.loc[:,['sil_score']] \
    .plot(kind='bar', color='green', legend=False, ax=ax0)
ax0.set_title('SILHOUETTE SCORE', fontsize=15)


cluster_scores.loc[:,['cluster_count']] \
    .plot(kind='bar', legend=False, ax=ax1);
ax1.set_title('CLUSTER COUNT', fontsize=15)

plt.xlabel('Beat Numbers')
plt.xticks(rotation=1);

# %% [markdown]
# Beat 6 seems to show the tightest clustering based on silhouette score.

# %% [markdown]
# ## 11 AM

# %%
hour = 11

# %%
subset_df = df[df.hour_of_day == hour]

# %%
X = pd.get_dummies(subset_df)

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# find best DBSCAN parameters
cluster_count = []
sil_score = []
eps_ = []
min_samples_ = []

for eps in [.1, .5, 1, 5, 10]:
    for min_samples in [5, 10, 25, 50]:
    
        # Defining the agglomerative clustering
        dbscan_cluster = DBSCAN(eps=eps, min_samples=min_samples)

        # Fit model
        clusters = dbscan_cluster.fit_predict(X_std)
        
        # capture cluster count
        cluster_count.append(len(set(clusters)) - (1 if -1 in clusters else 0))
        
        # capture model fit
        if pd.Series(clusters).nunique() > 1:
            sil_score.append(round(metrics.silhouette_score(X_std, clusters, metric='euclidean'), 3))
        else:
            sil_score.append(np.nan)
        
        # record parameter values
        eps_.append(eps)
        min_samples_.append(min_samples)

# %%
# tabulate param results from above
# sort by silhouette score & cluster count
pd.DataFrame(list(list(zip(sil_score, cluster_count, eps_, min_samples_))), 
            columns=['sil_score', 'cluster_count', 'eps', 'min_samples']) \
        .sort_values(by=['sil_score', 'cluster_count'], ascending=False)
# Out:
#     sil_score  cluster_count   eps  min_samples
# 16      0.616              2  10.0            5
# 17      0.616              2  10.0           10
# 18      0.616              1  10.0           25
# 19      0.616              1  10.0           50
# 12      0.300              5   5.0            5
# 13      0.300              5   5.0           10
# 8       0.296             22   1.0            5
# 14      0.290              3   5.0           25
# 15      0.290              3   5.0           50
# 9       0.197              8   1.0           10
# 10      0.041              2   1.0           25
# 4      -0.356             17   0.5            5
# 0         NaN              0   0.1            5
# 1         NaN              0   0.1           10
# 2         NaN              0   0.1           25
# 3         NaN              0   0.1           50
# 5         NaN              0   0.5           10
# 6         NaN              0   0.5           25
# 7         NaN              0   0.5           50
# 11        NaN              0   1.0           50

# %% [markdown]
# ## Model best parameters from above

# %%
dbscan_cluster = DBSCAN(eps=5, min_samples=5)
clusters = dbscan_cluster.fit_predict(X_std)
pd.Series(clusters).value_counts().plot(kind='pie', title='Cluster Distribution');

# %%
pd.Series(clusters).value_counts(dropna=False)
# Out:
# 0    1251
# 2      70
# 1      62
# 4      15
# 3      10
# dtype: int64

# %%
# format beat 6 data for plotting
subset_df = pd.concat([subset_df.reset_index(drop=True), pd.Series(clusters).rename('cluster')], axis=1)

# %%
subset_df = subset_df[subset_df.cluster != -1]

# %%
subset_df
# Out:
#       beat  cited_person_age                             charge_description  \
# 0     17.0              22.0  Failure to Control Speed to Avoid A Collision
# 1     10.0              38.0                Expired/No Arizona Registration
# 2     11.0              37.0                Expired/No Arizona Registration
# 3     12.0              23.0               Speed Greater Than R&P or Posted
# 4      6.0              27.0                         Suspended/Revoked D.L.
# ...    ...               ...                                            ...
# 1403  14.0              54.0  Failure to Control Speed to Avoid A Collision
# 1404  19.0              58.0               Speed Greater Than R&P or Posted
# 1405  12.0              26.0                         Suspended/Revoked D.L.
# 1406  15.0              40.0                          No Proof of Insurance
# 1407  19.0              42.0                         Suspended/Revoked D.L.
#
#       month  day_of_week  hour_of_day  cluster
# 0         7            5           11        0
# 1         7            2           11        0
# 2         7            1           11        0
# 3         7            2           11        0
# 4         7            1           11        0
# ...     ...          ...          ...      ...
# 1403     10            1           11        0
# 1404      9            3           11        0
# 1405     10            2           11        0
# 1406      9            3           11        1
# 1407     10            3           11        0
#
# [1408 rows x 7 columns]

# %%
df.groupby(['hour_of_day']).agg(['mean']).loc[:,['cited_person_age']]
# Out:
#             cited_person_age
#                         mean
# hour_of_day
# 0                  31.837684
# 1                  31.516905
# 2                  30.198049
# 3                  31.049133
# 4                  35.044521
# 5                  37.031026
# 6                  39.338930
# 7                  39.658452
# 8                  39.637596
# 9                  40.277037
# 10                 40.713469
# 11                 41.702415
# 12                 40.073920
# 13                 39.564381
# 14                 40.274648
# 15                 39.352417
# 16                 38.756442
# 17                 38.391462
# 18                 38.290000
# 19                 36.689893
# 20                 35.963458
# 21                 34.763109
# 22                 33.010256
# 23                 32.632037

# %%
subset_df.groupby(['hour_of_day', 'cluster']).agg(['mean']).loc[:,['cited_person_age']]
# Out:
#                     cited_person_age
#                                 mean
# hour_of_day cluster
# 11          0              42.204636
#             1              43.532258
#             2              32.242857
#             3              41.600000
#             4              36.466667

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharey=True, sharex=True, figsize=(6, 6))

df.groupby(['hour_of_day']).agg(['mean']).loc[:,['cited_person_age']].plot(ax=ax0, legend=False)
ax0.set_title('ALL CITATIONS', fontsize=15)

subset_df.groupby(['cluster', 'hour_of_day']).agg(['mean']).loc[:,['cited_person_age']].plot(ax=ax1, legend=False)
ax1.set_title('HOUR', fontsize=15)
ax1.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))

plt.xticks(rotation=60, horizontalalignment="right");

# %%
fig, (ax2, ax3) = plt.subplots(nrows=2, ncols=1, sharey=True, sharex=True, figsize=(6, 6))

df.groupby(['hour_of_day']).agg(['mean']).loc[:,['month', 'day_of_week']].plot(ax=ax2, legend=False)
ax2.set_title('ALL CITATIONS', fontsize=15)

subset_df.groupby(['cluster', 'hour_of_day']).agg(['mean']).loc[:,['month', 'day_of_week', 'hour_of_day']].plot(ax=ax3)
ax3.set_title('Hour', fontsize=15)
ax3.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))

plt.xticks(rotation=60, horizontalalignment="right");

# %%
subset_df.groupby(['cluster', 'charge_description']).agg(['mean']).loc[:,['cited_person_age']]
# Out:
#                                                       cited_person_age
#                                                                   mean
# cluster charge_description
# 0       Expired/No Arizona Registration                      38.725869
#         Fail to Obey Traffic Control Device                  41.891304
#         Fail to Stop For Red Signal                          47.112500
#         Fail to Stop at Stop Sign                            49.065789
#         Failure to Control Speed to Avoid A Collision        45.419890
#         Speed Greater Than R&P or Posted                     42.950588
#         Suspended/Revoked D.L.                               35.804348
# 1       No Proof of Insurance                                43.532258
# 2       Drug Paraphernalia-Possess/Use                       32.242857
# 3       DUI-Impaired to Slightest Degree                     41.600000
# 4       Expired/No Arizona Registration                      29.000000
#         Fail to Obey Traffic Control Device                  35.000000
#         Failure to Control Speed to Avoid A Collision        36.000000
#         Speed Greater Than R&P or Posted                     40.142857

# %%
fig, ax0 = plt.subplots(figsize=(6, 3))

df.groupby(['charge_description']).agg(['mean']).loc[:,['cited_person_age']].plot(ax=ax0, legend=False)
ax0.set_title('ALL CITATIONS', fontsize=15)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))

plt.xticks(rotation=60, horizontalalignment="right");

# %%
df.groupby(['charge_description']).agg(['mean']).loc[:,['cited_person_age']].loc[:,['cited_person_age']].reset_index()
# Out:
#                               charge_description cited_person_age
#                                                              mean
# 0               DUI-Impaired to Slightest Degree        34.341276
# 1                 Drug Paraphernalia-Possess/Use        29.933227
# 2                Expired/No Arizona Registration        36.928696
# 3            Fail to Obey Traffic Control Device        41.338172
# 4                    Fail to Stop For Red Signal        41.162198
# 5                      Fail to Stop at Stop Sign        39.881507
# 6  Failure to Control Speed to Avoid A Collision        40.754597
# 7                          No Proof of Insurance        36.684021
# 8               Speed Greater Than R&P or Posted        38.432995
# 9                         Suspended/Revoked D.L.        34.550875

# %%
subset_df.groupby(['cluster', 'charge_description']).agg(['mean']).loc[:,['cited_person_age']].reset_index()
# Out:
#    cluster                             charge_description cited_person_age
#                                                                       mean
# 0        0                Expired/No Arizona Registration        38.725869
# 1        0            Fail to Obey Traffic Control Device        41.891304
# 2        0                    Fail to Stop For Red Signal        47.112500
# 3        0                      Fail to Stop at Stop Sign        49.065789
# 4        0  Failure to Control Speed to Avoid A Collision        45.419890
# 5        0               Speed Greater Than R&P or Posted        42.950588
# 6        0                         Suspended/Revoked D.L.        35.804348
# 7        1                          No Proof of Insurance        43.532258
# 8        2                 Drug Paraphernalia-Possess/Use        32.242857
# 9        3               DUI-Impaired to Slightest Degree        41.600000
# 10       4                Expired/No Arizona Registration        29.000000
# 11       4            Fail to Obey Traffic Control Device        35.000000
# 12       4  Failure to Control Speed to Avoid A Collision        36.000000
# 13       4               Speed Greater Than R&P or Posted        40.142857

# %%
subset_df.groupby(['cluster', 'charge_description']).agg(['mean']).loc[:,['cited_person_age']].reset_index().merge(
df.groupby(['charge_description']).agg(['mean']).loc[:,['cited_person_age']].loc[:,['cited_person_age']].reset_index(),
how='left',
on='charge_description').plot()

# plt.xticks(rotation=60, horizontalalignment="right");

# %%
subset_df.groupby(['cluster', 'charge_description']).agg(['mean']).loc[:,['cited_person_age']].unstack().plot()

# %%
fig, ax1 = plt.subplots(figsize=(8, 3))

subset_df.groupby(['cluster', 'charge_description']).agg(['mean']).loc[:,['cited_person_age']].plot(ax=ax1, legend=False)
ax1.set_title('HOUR', fontsize=15)
ax1.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))

plt.xticks(rotation=60, horizontalalignment="right");

# %%
fig, (ax2, ax3) = plt.subplots(nrows=2, ncols=1, sharey=True, sharex=True, figsize=(6, 6))

df.drop('beat', axis=1).groupby(['charge_description']).agg(['mean']).loc[:,['month', 'day_of_week', 'hour_of_day']].plot(ax=ax2, legend=False)
ax2.set_title('ALL CITATIONS', fontsize=15)

beat_number_labels.groupby(['cluster', 'charge_description']).agg(['mean']).loc[:,['month', 'day_of_week', 'hour_of_day']].plot(ax=ax3)
ax3.set_title('BEAT NUMBER - ' + str(beat_number), fontsize=15)
ax3.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))

plt.xticks(rotation=60, horizontalalignment="right");

# %% [markdown]
# ### PCA

# %%
# Computing the first principal components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_std)

# %%
plt.figure(figsize=(15,10))

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pd.Series(clusters), alpha=.5);

# %% [markdown]
# ### t-SNE

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(X_std)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3574 samples in 0.005s...
# [t-SNE] Computed neighbors for 3574 samples in 0.397s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3574
# [t-SNE] Computed conditional probabilities for sample 2000 / 3574
# [t-SNE] Computed conditional probabilities for sample 3000 / 3574
# [t-SNE] Computed conditional probabilities for sample 3574 / 3574
# [t-SNE] Mean sigma: 0.677984
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.336636
# [t-SNE] KL divergence after 300 iterations: 1.234760

# %%
plt.figure(figsize=(10, 10))

plt.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %% [markdown]
# ### UMAP - iteration 1

# %%
umap_results = umap.UMAP(n_neighbors=5,
                      min_dist=0.3,
                      metric='correlation').fit_transform(X_std)

# %%
plt.figure(figsize=(10, 10))

plt.scatter(umap_results[:, 0], umap_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %% [markdown]
# ## Beat #7

# %%
beat_number = 7

# %%
beat_number_df = df[df.beat == beat_number]

# %%
X = pd.get_dummies(beat_number_df)

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# find best DBSCAN parameters
cluster_count = []
sil_score = []
eps_ = []
min_samples_ = []

for eps in [.1, .5, 1, 5, 10]:
    for min_samples in [5, 10, 25, 50]:
    
        # Defining the agglomerative clustering
        dbscan_cluster = DBSCAN(eps=eps, min_samples=min_samples)

        # Fit model
        clusters = dbscan_cluster.fit_predict(X_std)
        
        # capture cluster count
        cluster_count.append(len(set(clusters)) - (1 if -1 in clusters else 0))
        
        # capture model fit
        if pd.Series(clusters).nunique() > 1:
            sil_score.append(round(metrics.silhouette_score(X_std, clusters, metric='euclidean'), 3))
        else:
            sil_score.append(np.nan)
        
        # record parameter values
        eps_.append(eps)
        min_samples_.append(min_samples)

# %%
# tabulate param results from above
# sort by silhouette score & cluster count
pd.DataFrame(list(list(zip(sil_score, cluster_count, eps_, min_samples_))), 
            columns=['sil_score', 'cluster_count', 'eps', 'min_samples']) \
        .sort_values(by=['sil_score', 'cluster_count'], ascending=False)
# Out:
#     sil_score  cluster_count   eps  min_samples
# 8       0.288             22   1.0            5
# 12      0.253              2   5.0            5
# 13      0.253              2   5.0           10
# 14      0.253              2   5.0           25
# 15      0.253              2   5.0           50
# 9       0.175             18   1.0           10
# 10      0.041              6   1.0           25
# 11      0.021              1   1.0           50
# 6      -0.247              3   0.5           25
# 5      -0.257             17   0.5           10
# 0      -0.259              2   0.1            5
# 4      -0.359             45   0.5            5
# 16        NaN              1  10.0            5
# 17        NaN              1  10.0           10
# 18        NaN              1  10.0           25
# 19        NaN              1  10.0           50
# 1         NaN              0   0.1           10
# 2         NaN              0   0.1           25
# 3         NaN              0   0.1           50
# 7         NaN              0   0.5           50

# %% [markdown]
# ## Model best parameters from above

# %%
dbscan_cluster = DBSCAN(eps=1, min_samples=25)
clusters = dbscan_cluster.fit_predict(X_std)
pd.Series(clusters).value_counts().plot(kind='pie', title='Cluster Distribution');

# %%
pd.Series(clusters).value_counts(dropna=False)
# Out:
# -1    1554
#  0     842
#  4     117
#  2      92
#  1      53
#  3      35
#  5      26
# dtype: int64

# %%
# format beat 6 data for plotting
beat_number_labels = pd.concat([beat_number_df.reset_index(drop=True).drop('beat', axis=1), pd.Series(clusters).rename('cluster')], axis=1)

# %%
beat_number_labels = beat_number_labels[beat_number_labels.cluster != -1]

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharey=True, sharex=True, figsize=(6, 6))

df.drop('beat', axis=1).groupby(['charge_description']).agg(['mean']).loc[:,['cited_person_age']].plot(ax=ax0, legend=False)
ax0.set_title('ALL CITATIONS', fontsize=15)

beat_number_labels.groupby(['cluster', 'charge_description']).agg(['mean']).loc[:,['cited_person_age']].plot(ax=ax1, legend=False)
ax1.set_title('BEAT NUMBER - ' + str(beat_number), fontsize=15)
ax1.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))

plt.xticks(rotation=60, horizontalalignment="right");

# %%
fig, (ax2, ax3) = plt.subplots(nrows=2, ncols=1, sharey=True, sharex=True, figsize=(6, 6))

df.drop('beat', axis=1).groupby(['charge_description']).agg(['mean']).loc[:,['month', 'day_of_week', 'hour_of_day']].plot(ax=ax2, legend=False)
ax2.set_title('ALL CITATIONS', fontsize=15)

beat_number_labels.groupby(['cluster', 'charge_description']).agg(['mean']).loc[:,['month', 'day_of_week', 'hour_of_day']].plot(ax=ax3)
ax3.set_title('BEAT NUMBER - ' + str(beat_number), fontsize=15)
ax3.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))

plt.xticks(rotation=60, horizontalalignment="right");

# %% [markdown]
# ### PCA

# %%
# Computing the first principal components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_std)

# %%
plt.figure(figsize=(15,10))

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pd.Series(clusters), alpha=.5);

# %% [markdown]
# ### t-SNE

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(X_std)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2719 samples in 0.005s...
# [t-SNE] Computed neighbors for 2719 samples in 0.281s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2719
# [t-SNE] Computed conditional probabilities for sample 2000 / 2719
# [t-SNE] Computed conditional probabilities for sample 2719 / 2719
# [t-SNE] Mean sigma: 0.729974
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.118870
# [t-SNE] KL divergence after 300 iterations: 1.109566

# %%
plt.figure(figsize=(10, 10))

plt.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %% [markdown]
# ### UMAP - iteration 1

# %%
umap_results = umap.UMAP(n_neighbors=5,
                      min_dist=0.3,
                      metric='correlation').fit_transform(X_std)

# %%
plt.figure(figsize=(10, 10))

plt.scatter(umap_results[:, 0], umap_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %% [markdown]
# ## Beat #20

# %%
beat_number = 20

# %%
beat_number_df = df[df.beat == beat_number]

# %%
X = pd.get_dummies(beat_number_df)

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# find best DBSCAN parameters
cluster_count = []
sil_score = []
eps_ = []
min_samples_ = []

for eps in [.1, .5, 1, 5, 10]:
    for min_samples in [5, 10, 25, 50]:
    
        # Defining the agglomerative clustering
        dbscan_cluster = DBSCAN(eps=eps, min_samples=min_samples)

        # Fit model
        clusters = dbscan_cluster.fit_predict(X_std)
        
        # capture cluster count
        cluster_count.append(len(set(clusters)) - (1 if -1 in clusters else 0))
        
        # capture model fit
        if pd.Series(clusters).nunique() > 1:
            sil_score.append(round(metrics.silhouette_score(X_std, clusters, metric='euclidean'), 3))
        else:
            sil_score.append(np.nan)
        
        # record parameter values
        eps_.append(eps)
        min_samples_.append(min_samples)

# %%
# tabulate param results from above
# sort by silhouette score & cluster count
pd.DataFrame(list(list(zip(sil_score, cluster_count, eps_, min_samples_))), 
            columns=['sil_score', 'cluster_count', 'eps', 'min_samples']) \
        .sort_values(by=['sil_score', 'cluster_count'], ascending=False)
# Out:
#     sil_score  cluster_count   eps  min_samples
# 19      0.561              1  10.0           50
# 12      0.488              8   5.0            5
# 13      0.488              8   5.0           10
# 14      0.476              6   5.0           25
# 15      0.457              5   5.0           50
# 8       0.273             21   1.0            5
# 9       0.225              9   1.0           10
# 10      0.056              2   1.0           25
# 11     -0.023              2   1.0           50
# 5      -0.248              5   0.5           10
# 4      -0.255             20   0.5            5
# 16        NaN              1  10.0            5
# 17        NaN              1  10.0           10
# 18        NaN              1  10.0           25
# 0         NaN              0   0.1            5
# 1         NaN              0   0.1           10
# 2         NaN              0   0.1           25
# 3         NaN              0   0.1           50
# 6         NaN              0   0.5           25
# 7         NaN              0   0.5           50

# %% [markdown]
# ## Model best parameters from above

# %%
dbscan_cluster = DBSCAN(eps=5, min_samples=5)
clusters = dbscan_cluster.fit_predict(X_std)
pd.Series(clusters).value_counts().plot(kind='pie', title='Cluster Distribution');

# %%
pd.Series(clusters).value_counts(dropna=False)
# Out:
# 0    1464
# 3      71
# 4      65
# 2      62
# 1      50
# 5      37
# 6      21
# 7      19
# dtype: int64

# %%
# format beat 6 data for plotting
beat_number_labels = pd.concat([beat_number_df.reset_index(drop=True).drop('beat', axis=1), pd.Series(clusters).rename('cluster')], axis=1)

# %%
beat_number_labels = beat_number_labels[beat_number_labels.cluster != -1]

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharey=True, sharex=True, figsize=(6, 6))

df.drop('beat', axis=1).groupby(['charge_description']).agg(['mean']).loc[:,['cited_person_age']].plot(ax=ax0, legend=False)
ax0.set_title('ALL CITATIONS', fontsize=15)

beat_number_labels.groupby(['cluster', 'charge_description']).agg(['mean']).loc[:,['cited_person_age']].plot(ax=ax1, legend=False)
ax1.set_title('BEAT NUMBER - ' + str(beat_number), fontsize=15)
ax1.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))

plt.xticks(rotation=60, horizontalalignment="right");

# %%
fig, (ax2, ax3) = plt.subplots(nrows=2, ncols=1, sharey=True, sharex=True, figsize=(6, 6))

df.drop('beat', axis=1).groupby(['charge_description']).agg(['mean']).loc[:,['month', 'day_of_week', 'hour_of_day']].plot(ax=ax2, legend=False)
ax2.set_title('ALL CITATIONS', fontsize=15)

beat_number_labels.groupby(['cluster', 'charge_description']).agg(['mean']).loc[:,['month', 'day_of_week', 'hour_of_day']].plot(ax=ax3)
ax3.set_title('BEAT NUMBER - ' + str(beat_number), fontsize=15)
ax3.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))

plt.xticks(rotation=60, horizontalalignment="right");

# %% [markdown]
# ### PCA

# %%
# Computing the first principal components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_std)

# %%
plt.figure(figsize=(15,10))

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pd.Series(clusters), alpha=.5);

# %% [markdown]
# ### t-SNE

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(X_std)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1789 samples in 0.004s...
# [t-SNE] Computed neighbors for 1789 samples in 0.128s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1789
# [t-SNE] Computed conditional probabilities for sample 1789 / 1789
# [t-SNE] Mean sigma: 0.641126
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 61.325092
# [t-SNE] KL divergence after 300 iterations: 0.882500

# %%
plt.figure(figsize=(10, 10))

plt.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %% [markdown]
# ### UMAP - iteration 1

# %%
umap_results = umap.UMAP(n_neighbors=5,
                      min_dist=0.3,
                      metric='correlation').fit_transform(X_std)

# %%
plt.figure(figsize=(10, 10))

plt.scatter(umap_results[:, 0], umap_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %%
# visualize dendrogram
plt.figure(figsize=(20,10))
dendrogram(linkage(pd.get_dummies(beat_number_labels), method='complete'));
# plt.xticks(rotation=45, horizontalalignment="right");

# %%
# Defining the agglomerative clustering
agg_cluster = AgglomerativeClustering(linkage='average', 
                                      affinity='cosine',
                                      n_clusters=4)

# Fit model
beat_number_labels['labels2'] = agg_cluster.fit_predict(X_std)

# %%
beat_number_labels.labels2.value_counts()
# Out:
# 0    1182
# 1     935
# 2     360
# 3     242
# Name: labels2, dtype: int64

# %%
beat_number_labels.head()
# Out:
#    cited_person_age                             charge_description  month  \
# 0              61.0               Speed Greater Than R&P or Posted      7
# 1              59.0               Speed Greater Than R&P or Posted      7
# 2              27.0                Expired/No Arizona Registration      7
# 3              23.0               Speed Greater Than R&P or Posted      7
# 4              20.0  Failure to Control Speed to Avoid A Collision      7
#
#    day_of_week  week_of_year  hour_of_day  cluster  labels2
# 0            2            28            8        0        1
# 1            3            28            8        0        1
# 2            0            29           14        0        2
# 3            3            28            0        0        1
# 4            2            28           16        0        0

# %%
beat_number_labels.groupby(['labels2', 'charge_description']).median()
# Out:
#                                                        cited_person_age  \
# labels2 charge_description
# 0       Drug Paraphernalia-Possess/Use                             26.0
#         Fail to Obey Traffic Control Device                        34.0
#         Fail to Stop For Red Signal                                33.0
#         Fail to Stop at Stop Sign                                  34.0
#         Failure to Control Speed to Avoid A Collision              31.0
#         No Proof of Insurance                                      31.0
#         Suspended/Revoked D.L.                                     27.0
# 1       Speed Greater Than R&P or Posted                           31.0
# 2       Expired/No Arizona Registration                            32.0
# 3       DUI-Impaired to Slightest Degree                           28.0
#
#                                                        month  day_of_week  \
# labels2 charge_description
# 0       Drug Paraphernalia-Possess/Use                   7.0          4.0
#         Fail to Obey Traffic Control Device              8.0          3.0
#         Fail to Stop For Red Signal                      7.0          3.5
#         Fail to Stop at Stop Sign                        8.0          3.0
#         Failure to Control Speed to Avoid A Collision    8.0          3.0
#         No Proof of Insurance                            7.0          4.0
#         Suspended/Revoked D.L.                           7.0          3.0
# 1       Speed Greater Than R&P or Posted                 7.0          3.0
# 2       Expired/No Arizona Registration                  7.0          2.0
# 3       DUI-Impaired to Slightest Degree                 8.0          4.0
#
#                                                        week_of_year  \
# labels2 charge_description
# 0       Drug Paraphernalia-Possess/Use                         29.0
#         Fail to Obey Traffic Control Device                    33.0
#         Fail to Stop For Red Signal                            28.0
#         Fail to Stop at Stop Sign                              33.0
#         Failure to Control Speed to Avoid A Collision          34.0
#         No Proof of Insurance                                  28.0
#         Suspended/Revoked D.L.                                 28.0
# 1       Speed Greater Than R&P or Posted                       31.0
# 2       Expired/No Arizona Registration                        30.0
# 3       DUI-Impaired to Slightest Degree                       32.0
#
#                                                        hour_of_day  cluster
# labels2 charge_description
# 0       Drug Paraphernalia-Possess/Use                        17.0      1.0
#         Fail to Obey Traffic Control Device                   13.0      0.0
#         Fail to Stop For Red Signal                           14.0      0.0
#         Fail to Stop at Stop Sign                             13.0      0.0
#         Failure to Control Speed to Avoid A Collision         14.0      0.0
#         No Proof of Insurance                                 13.0      0.0
#         Suspended/Revoked D.L.                                14.0      0.0
# 1       Speed Greater Than R&P or Posted                       9.0      0.0
# 2       Expired/No Arizona Registration                       13.0      0.0
# 3       DUI-Impaired to Slightest Degree                       2.0      0.0

# %% [markdown]
# Agglomerative clustering also seems to be dominated by categorical variables.  As was DBSCAN.
