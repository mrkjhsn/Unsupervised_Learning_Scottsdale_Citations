# %% [markdown]
# # CITATION LOCATION - clustering analysis
# Holding other variables constant and only examining for location, am I able to find areas of the city with specific types of clustering?

# %% [markdown]
# ### IMPORT LIBRARIES AND DATA

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import datetime
import glob
pd.set_option('display.max_columns', None)
sns.set(style='darkgrid')
# plt.style.use('bmh')
plt.rcParams['patch.edgecolor'] = 'none'
import jenkspy

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
# read in data that has already been preprocessed
df = pd.read_csv('data/clustering_features.csv')

# %%
df.shape
# Out:
# (36626, 11)

# %%
df.head()
# Out:
#    beat  cited_person_age  citation_time                charge_description  \
# 0  12.0              19.0            747  Speed Greater Than R&P or Posted
# 1  12.0              36.0            800  Speed Greater Than R&P or Posted
# 2   7.0              61.0            853  Speed Greater Than R&P or Posted
# 3   7.0              59.0            843  Speed Greater Than R&P or Posted
# 4  19.0              23.0           2215  Speed Greater Than R&P or Posted
#
#            street  month  day_of_week  week_of_year  hour_of_day  \
# 0       E Shea Bl      7            2            28            7
# 1       E Shea Bl      7            2            28            8
# 2  N Goldwater Bl      7            2            28            8
# 3  N Goldwater Bl      7            3            28            8
# 4       N Pima Rd      7            5            27           22
#
#                 place_id      age_breaks
# 0       E Shea Bl - 6xxx  (17.999, 24.0]
# 1       E Shea Bl - 6xxx    (30.0, 39.0]
# 2  N Goldwater Bl - 4xxx    (51.0, 97.0]
# 3  N Goldwater Bl - 4xxx    (51.0, 97.0]
# 4       N Pima Rd - 2xxx  (17.999, 24.0]

# %%
# drop place id for the time being
df.drop(['place_id'], axis=1, inplace=True)

# %%
# drop features I don't want to use for now
df.drop(['citation_time'], axis=1, inplace=True)
# df.drop(['age_breaks'], axis=1, inplace=True)
# df.drop(['beat'], axis=1, inplace=True)
df.drop(['age_breaks'], axis=1, inplace=True)

# %%
df.drop(['street'], axis=1, inplace=True)

# %%
# drop citations where beat is null
# otherwise this creates problems for modeling

df.drop(df[df.beat.isnull()].index, inplace=True)

# %%
# verify no null values remain
df.isnull().sum()
# Out:
# beat                  0
# cited_person_age      0
# charge_description    0
# month                 0
# day_of_week           0
# week_of_year          0
# hour_of_day           0
# dtype: int64

# %%
df.head()
# Out:
#    beat  cited_person_age                charge_description  month  \
# 0  12.0              19.0  Speed Greater Than R&P or Posted      7
# 1  12.0              36.0  Speed Greater Than R&P or Posted      7
# 2   7.0              61.0  Speed Greater Than R&P or Posted      7
# 3   7.0              59.0  Speed Greater Than R&P or Posted      7
# 4  19.0              23.0  Speed Greater Than R&P or Posted      7
#
#    day_of_week  week_of_year  hour_of_day
# 0            2            28            7
# 1            2            28            8
# 2            2            28            8
# 3            3            28            8
# 4            5            27           22

# %%
# identify unique beat locations
df.beat.unique()
# Out:
# array([12.,  7., 19., 11.,  6., 14., 10., 18.,  3., 15.,  1., 16., 17.,
#        13., 99.,  4., 20.,  8.,  5.,  9.,  2.])

# %%
X = pd.get_dummies(df.drop(['beat'], axis=1))

# %%
X.head()
# Out:
#    cited_person_age  month  day_of_week  week_of_year  hour_of_day  \
# 0              19.0      7            2            28            7
# 1              36.0      7            2            28            8
# 2              61.0      7            2            28            8
# 3              59.0      7            3            28            8
# 4              23.0      7            5            27           22
#
#    charge_description_DUI-Impaired to Slightest Degree  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    charge_description_Drug Paraphernalia-Possess/Use  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    charge_description_Expired/No Arizona Registration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    charge_description_Fail to Obey Traffic Control Device  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    charge_description_Fail to Stop For Red Signal  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    charge_description_Fail to Stop at Stop Sign  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    charge_description_Failure to Control Speed to Avoid A Collision  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    charge_description_No Proof of Insurance  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#    charge_description_Speed Greater Than R&P or Posted  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    charge_description_Suspended/Revoked D.L.
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0

# %%
X.shape
# Out:
# (36391, 15)

# %%
# Standarizing the features
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# which beats seem to be the most clustered?
sil_score = []
cluster_count = []

for location in list(df.beat.unique()):
    
    df2 = df[df.beat == location]
    X = pd.get_dummies(df2.drop(['beat'], axis=1))
    
    scaler = StandardScaler()
    X_std = scaler.fit_transform(X)
    
    # Defining the agglomerative clustering
    dbscan_cluster = DBSCAN(eps=.7, min_samples=20)

    # Fit model
    clusters = dbscan_cluster.fit_predict(X_std)
    
    # capture cluster count
    cluster_count.append(len(set(clusters)) - (1 if -1 in clusters else 0))

    # capture model fit
    if pd.Series(clusters).nunique() > 1:
        sil_score.append(round(metrics.silhouette_score(X_std, clusters, metric='euclidean'), 3))
    else:
        sil_score.append(np.nan)

# %% [markdown]
# ### Which beats seem the most clustered?

# %%
cluster_scores = pd.DataFrame(list(zip(list(df.beat.unique()), sil_score, cluster_count)),
             columns=['beat', 'sil_score', 'cluster_count']) \
        .set_index('beat') \
        .sort_values(by=['sil_score', 'cluster_count'], ascending=False)

cluster_scores
# Out:
#       sil_score  cluster_count
# beat
# 9.0       0.015              1
# 1.0      -0.086              1
# 6.0      -0.090              8
# 5.0      -0.092              2
# 19.0     -0.115              2
# 7.0      -0.142              3
# 13.0     -0.150              1
# 17.0     -0.151              2
# 20.0     -0.159              4
# 10.0     -0.160              3
# 12.0     -0.164              1
# 3.0      -0.170              2
# 2.0      -0.177              1
# 18.0     -0.199              2
# 8.0      -0.203              2
# 4.0      -0.207              2
# 14.0     -0.253              3
# 11.0        NaN              0
# 15.0        NaN              0
# 16.0        NaN              0
# 99.0        NaN              0

# %%
# plot silhouette score and cluster count
fig, (ax0, ax1) = plt.subplots(nrows=2,ncols=1, sharex=True, figsize=(10, 6))

cluster_scores.loc[:,['sil_score']] \
    .plot(kind='bar', color='green', legend=False, ax=ax0)
ax0.set_title('SILHOUETTE SCORE', fontsize=15)


cluster_scores.loc[:,['cluster_count']] \
    .plot(kind='bar', legend=False, ax=ax1);
ax1.set_title('CLUSTER COUNT', fontsize=15)

plt.xlabel('Beat Numbers')
plt.xticks(rotation=1);

# %% [markdown]
# Beat 6 seems to show the tightest clustering based on silhouette score.

# %% [markdown]
# ## Beat #6

# %%
beat_number = 6

# %%
beat_number_df = df[df.beat == beat_number]

# %%
X = pd.get_dummies(beat_number_df)

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# find best DBSCAN parameters
cluster_count = []
sil_score = []
eps_ = []
min_samples_ = []

for eps in [.1, .5, 1, 5, 10]:
    for min_samples in [5, 10, 25, 50]:
    
        # Defining the agglomerative clustering
        dbscan_cluster = DBSCAN(eps=eps, min_samples=min_samples)

        # Fit model
        clusters = dbscan_cluster.fit_predict(X_std)
        
        # capture cluster count
        cluster_count.append(len(set(clusters)) - (1 if -1 in clusters else 0))
        
        # capture model fit
        if pd.Series(clusters).nunique() > 1:
            sil_score.append(round(metrics.silhouette_score(X_std, clusters, metric='euclidean'), 3))
        else:
            sil_score.append(np.nan)
        
        # record parameter values
        eps_.append(eps)
        min_samples_.append(min_samples)

# %%
# tabulate param results from above
# sort by silhouette score & cluster count
pd.DataFrame(list(list(zip(sil_score, cluster_count, eps_, min_samples_))), 
            columns=['sil_score', 'cluster_count', 'eps', 'min_samples']) \
        .sort_values(by=['sil_score', 'cluster_count'], ascending=False)
# Out:
#     sil_score  cluster_count   eps  min_samples
# 19      0.015              1  10.0           50
# 10     -0.086              1   1.0           25
# 4      -0.090              8   0.5            5
# 18     -0.092              2  10.0           25
# 2      -0.115              2   0.1           25
# 1      -0.142              3   0.1           10
# 13     -0.150              1   5.0           10
# 12     -0.151              2   5.0            5
# 16     -0.159              4  10.0            5
# 6      -0.160              3   0.5           25
# 0      -0.164              1   0.1            5
# 8      -0.170              2   1.0            5
# 7      -0.199              2   0.5           50
# 17     -0.203              2  10.0           10
# 15     -0.207              2   5.0           50
# 5      -0.253              3   0.5           10
# 3         NaN              0   0.1           50
# 9         NaN              0   1.0           10
# 11        NaN              0   1.0           50
# 14        NaN              0   5.0           25

# %% [markdown]
# ## Model best parameters from above

# %%
dbscan_cluster = DBSCAN(eps=5, min_samples=5)
clusters = dbscan_cluster.fit_predict(X_std)
pd.Series(clusters).value_counts()
# Out:
# 0    3031
# 1     189
# 3     184
# 2     170
# dtype: int64

# %%
# format beat 16 data for plotting
beat_number_labels = pd.concat([beat_number_df.reset_index(drop=True).drop('beat', axis=1), pd.Series(clusters).rename('cluster')], axis=1)

# %%
beat_number_labels
# Out:
#       cited_person_age                             charge_description  month  \
# 0                 57.0                Expired/No Arizona Registration      7
# 1                 24.0                      Fail to Stop at Stop Sign      7
# 2                 22.0                Expired/No Arizona Registration      7
# 3                 62.0            Fail to Obey Traffic Control Device      7
# 4                 47.0                Expired/No Arizona Registration      7
# ...                ...                                            ...    ...
# 3569              24.0                      Fail to Stop at Stop Sign      9
# 3570              40.0               Speed Greater Than R&P or Posted      9
# 3571              56.0  Failure to Control Speed to Avoid A Collision     10
# 3572              54.0                         Suspended/Revoked D.L.     10
# 3573              21.0            Fail to Obey Traffic Control Device      9
#
#       day_of_week  week_of_year  hour_of_day  cluster
# 0               5            27           10        0
# 1               0            28           19        0
# 2               1            28           18        0
# 3               2            28           15        0
# 4               2            28            8        0
# ...           ...           ...          ...      ...
# 3569            5            39           16        0
# 3570            5            39           21        0
# 3571            2            40           17        1
# 3572            3            40            1        0
# 3573            6            39           23        0
#
# [3574 rows x 7 columns]

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,ncols=1, sharex=True, figsize=(8, 6))

df.drop('beat', axis=1).groupby(['charge_description']).agg(['mean']).plot(ax=ax0, legend=False)
ax0.set_title('ALL CITATIONS', fontsize=15)

beat_number_labels.groupby(['cluster', 'charge_description']).agg(['mean']).plot(ax=ax1)
ax1.set_title('BEAT NUMBER - ' + str(beat_number), fontsize=15)

plt.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))
plt.xticks(rotation=45, horizontalalignment="right");
# plt.xlabel('CHARGE DESCRIPTION', fontsize=13);

# %% [markdown]
# ### PCA

# %%
# Computing the first principal components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_std)

# %%
plt.figure(figsize=(15,10))

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pd.Series(clusters), alpha=.5);

# %% [markdown]
# ### t-SNE

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(X_std)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3574 samples in 0.008s...
# [t-SNE] Computed neighbors for 3574 samples in 0.409s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3574
# [t-SNE] Computed conditional probabilities for sample 2000 / 3574
# [t-SNE] Computed conditional probabilities for sample 3000 / 3574
# [t-SNE] Computed conditional probabilities for sample 3574 / 3574
# [t-SNE] Mean sigma: 0.757619
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.137512
# [t-SNE] KL divergence after 300 iterations: 1.213243

# %%
plt.figure(figsize=(10, 10))

plt.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %% [markdown]
# ### UMAP - iteration 1

# %%
umap_results = umap.UMAP(n_neighbors=5,
                      min_dist=0.3,
                      metric='correlation').fit_transform(X_std)

# %%
plt.figure(figsize=(10, 10))

plt.scatter(umap_results[:, 0], umap_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %% [markdown]
# ## Beat #7

# %%
beat_number = 7

# %%
beat_number_df = df[df.beat == beat_number]

# %%
X = pd.get_dummies(beat_number_df)

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# find best DBSCAN parameters
cluster_count = []
sil_score = []
eps_ = []
min_samples_ = []

for eps in [.1, .5, 1, 5, 10]:
    for min_samples in [5, 10, 25, 50]:
    
        # Defining the agglomerative clustering
        dbscan_cluster = DBSCAN(eps=eps, min_samples=min_samples)

        # Fit model
        clusters = dbscan_cluster.fit_predict(X_std)
        
        # capture cluster count
        cluster_count.append(len(set(clusters)) - (1 if -1 in clusters else 0))
        
        # capture model fit
        if pd.Series(clusters).nunique() > 1:
            sil_score.append(round(metrics.silhouette_score(X_std, clusters, metric='euclidean'), 3))
        else:
            sil_score.append(np.nan)
        
        # record parameter values
        eps_.append(eps)
        min_samples_.append(min_samples)

# %%
# tabulate param results from above
# sort by silhouette score & cluster count
pd.DataFrame(list(list(zip(sil_score, cluster_count, eps_, min_samples_))), 
            columns=['sil_score', 'cluster_count', 'eps', 'min_samples']) \
        .sort_values(by=['sil_score', 'cluster_count'], ascending=False)
# Out:
#     sil_score  cluster_count   eps  min_samples
# 12      0.238              2   5.0            5
# 13      0.238              2   5.0           10
# 14      0.238              2   5.0           25
# 15      0.238              2   5.0           50
# 8       0.160             32   1.0            5
# 9       0.097             18   1.0           10
# 11     -0.015              1   1.0           50
# 10     -0.143              6   1.0           25
# 6      -0.264              2   0.5           25
# 5      -0.278             16   0.5           10
# 4      -0.341             42   0.5            5
# 16        NaN              1  10.0            5
# 17        NaN              1  10.0           10
# 18        NaN              1  10.0           25
# 19        NaN              1  10.0           50
# 0         NaN              0   0.1            5
# 1         NaN              0   0.1           10
# 2         NaN              0   0.1           25
# 3         NaN              0   0.1           50
# 7         NaN              0   0.5           50

# %% [markdown]
# ## Model best parameters from above

# %%
dbscan_cluster = DBSCAN(eps=5, min_samples=5)
clusters = dbscan_cluster.fit_predict(X_std)
pd.Series(clusters).value_counts()
# Out:
# 0    2598
# 1     121
# dtype: int64

# %%
# format beat 16 data for plotting
beat_number_labels = pd.concat([beat_number_df.reset_index(drop=True).drop('beat', axis=1), pd.Series(clusters).rename('cluster')], axis=1)

# %%
beat_number_labels
# Out:
#       cited_person_age                             charge_description  month  \
# 0                 61.0               Speed Greater Than R&P or Posted      7
# 1                 59.0               Speed Greater Than R&P or Posted      7
# 2                 27.0                Expired/No Arizona Registration      7
# 3                 23.0               Speed Greater Than R&P or Posted      7
# 4                 20.0  Failure to Control Speed to Avoid A Collision      7
# ...                ...                                            ...    ...
# 2714              27.0                         Suspended/Revoked D.L.     10
# 2715              23.0               Speed Greater Than R&P or Posted      9
# 2716              23.0               Speed Greater Than R&P or Posted      9
# 2717              24.0                      Fail to Stop at Stop Sign      9
# 2718              74.0                          No Proof of Insurance      9
#
#       day_of_week  week_of_year  hour_of_day  cluster
# 0               2            28            8        0
# 1               3            28            8        0
# 2               0            29           14        0
# 3               3            28            0        0
# 4               2            28           16        0
# ...           ...           ...          ...      ...
# 2714            1            40           23        0
# 2715            3            39           12        0
# 2716            5            39            7        0
# 2717            4            39           18        0
# 2718            4            39           21        0
#
# [2719 rows x 7 columns]

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,ncols=1, sharex=True, figsize=(8, 6))

df.drop('beat', axis=1).groupby(['charge_description']).agg(['mean']).plot(ax=ax0, legend=False)
ax0.set_title('ALL CITATIONS', fontsize=15)

beat_number_labels.groupby(['cluster', 'charge_description']).agg(['mean']).plot(ax=ax1)
ax1.set_title('BEAT NUMBER - ' + str(beat_number), fontsize=15)

plt.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))
plt.xticks(rotation=45, horizontalalignment="right");
# plt.xlabel('CHARGE DESCRIPTION', fontsize=13);

# %% [markdown]
# ### PCA

# %%
# Computing the first principal components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_std)

# %%
plt.figure(figsize=(15,10))

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pd.Series(clusters), alpha=.5);

# %% [markdown]
# ### t-SNE

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(X_std)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2719 samples in 0.006s...
# [t-SNE] Computed neighbors for 2719 samples in 0.271s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2719
# [t-SNE] Computed conditional probabilities for sample 2000 / 2719
# [t-SNE] Computed conditional probabilities for sample 2719 / 2719
# [t-SNE] Mean sigma: 0.795434
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.613846
# [t-SNE] KL divergence after 300 iterations: 1.055585

# %%
plt.figure(figsize=(10, 10))

plt.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %% [markdown]
# ### UMAP - iteration 1

# %%
umap_results = umap.UMAP(n_neighbors=5,
                      min_dist=0.3,
                      metric='correlation').fit_transform(X_std)

# %%
plt.figure(figsize=(10, 10))

plt.scatter(umap_results[:, 0], umap_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %% [markdown]
# ## Beat #20

# %%
beat_number = 20

# %%
beat_number_df = df[df.beat == beat_number]

# %%
X = pd.get_dummies(beat_number_df)

scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# find best DBSCAN parameters
cluster_count = []
sil_score = []
eps_ = []
min_samples_ = []

for eps in [.1, .5, 1, 5, 10]:
    for min_samples in [5, 10, 25, 50]:
    
        # Defining the agglomerative clustering
        dbscan_cluster = DBSCAN(eps=eps, min_samples=min_samples)

        # Fit model
        clusters = dbscan_cluster.fit_predict(X_std)
        
        # capture cluster count
        cluster_count.append(len(set(clusters)) - (1 if -1 in clusters else 0))
        
        # capture model fit
        if pd.Series(clusters).nunique() > 1:
            sil_score.append(round(metrics.silhouette_score(X_std, clusters, metric='euclidean'), 3))
        else:
            sil_score.append(np.nan)
        
        # record parameter values
        eps_.append(eps)
        min_samples_.append(min_samples)

# %%
# tabulate param results from above
# sort by silhouette score & cluster count
pd.DataFrame(list(list(zip(sil_score, cluster_count, eps_, min_samples_))), 
            columns=['sil_score', 'cluster_count', 'eps', 'min_samples']) \
        .sort_values(by=['sil_score', 'cluster_count'], ascending=False)
# Out:
#     sil_score  cluster_count   eps  min_samples
# 19      0.543              1  10.0           50
# 12      0.457              8   5.0            5
# 13      0.457              8   5.0           10
# 14      0.445              6   5.0           25
# 15      0.427              5   5.0           50
# 10      0.209              1   1.0           25
# 9       0.208              5   1.0           10
# 8       0.191             23   1.0            5
# 11     -0.061              3   1.0           50
# 4      -0.317             23   0.5            5
# 5      -0.343              8   0.5           10
# 16        NaN              1  10.0            5
# 17        NaN              1  10.0           10
# 18        NaN              1  10.0           25
# 0         NaN              0   0.1            5
# 1         NaN              0   0.1           10
# 2         NaN              0   0.1           25
# 3         NaN              0   0.1           50
# 6         NaN              0   0.5           25
# 7         NaN              0   0.5           50

# %% [markdown]
# ## Model best parameters from above

# %%
dbscan_cluster = DBSCAN(eps=5, min_samples=5)
clusters = dbscan_cluster.fit_predict(X_std)
pd.Series(clusters).value_counts()
# Out:
# 0    1464
# 3      71
# 4      65
# 2      62
# 1      50
# 5      37
# 6      21
# 7      19
# dtype: int64

# %%
# format beat 16 data for plotting
beat_number_labels = pd.concat([beat_number_df.reset_index(drop=True).drop('beat', axis=1), pd.Series(clusters).rename('cluster')], axis=1)

# %%
beat_number_labels
# Out:
#       cited_person_age                             charge_description  month  \
# 0                 24.0               Speed Greater Than R&P or Posted      7
# 1                 68.0               Speed Greater Than R&P or Posted      7
# 2                 68.0               Speed Greater Than R&P or Posted      7
# 3                 28.0               Speed Greater Than R&P or Posted      7
# 4                 24.0  Failure to Control Speed to Avoid A Collision      7
# ...                ...                                            ...    ...
# 1784              46.0                Expired/No Arizona Registration      9
# 1785              33.0                      Fail to Stop at Stop Sign      9
# 1786              21.0  Failure to Control Speed to Avoid A Collision     10
# 1787              76.0  Failure to Control Speed to Avoid A Collision     10
# 1788              35.0                      Fail to Stop at Stop Sign      9
#
#       day_of_week  week_of_year  hour_of_day  cluster
# 0               3            28           21        0
# 1               6            28           13        0
# 2               6            28           13        0
# 3               5            28            5        0
# 4               1            28           13        0
# ...           ...           ...          ...      ...
# 1784            4            39           21        4
# 1785            4            39            5        0
# 1786            2            40            8        0
# 1787            2            40            9        0
# 1788            5            39           22        0
#
# [1789 rows x 7 columns]

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,ncols=1, sharex=True, figsize=(8, 6))

df.drop('beat', axis=1).groupby(['charge_description']).agg(['mean']).plot(ax=ax0, legend=False)
ax0.set_title('ALL CITATIONS', fontsize=15)

beat_number_labels.groupby(['cluster', 'charge_description']).agg(['mean']).plot(ax=ax1)
ax1.set_title('BEAT NUMBER - ' + str(beat_number), fontsize=15)

plt.legend(loc='center left', bbox_to_anchor=(1.0, 1.1))
plt.xticks(rotation=45, horizontalalignment="right");
# plt.xlabel('CHARGE DESCRIPTION', fontsize=13);

# %% [markdown]
# ### PCA

# %%
# Computing the first principal components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_std)

# %%
plt.figure(figsize=(15,10))

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=pd.Series(clusters), alpha=.5);

# %% [markdown]
# ### t-SNE

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(X_std)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1789 samples in 0.005s...
# [t-SNE] Computed neighbors for 1789 samples in 0.124s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1789
# [t-SNE] Computed conditional probabilities for sample 1789 / 1789
# [t-SNE] Mean sigma: 0.704876
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 60.828701
# [t-SNE] KL divergence after 300 iterations: 0.856247

# %%
plt.figure(figsize=(10, 10))

plt.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=.5, c=pd.Series(clusters));

# %% [markdown]
# ### UMAP - iteration 1

# %%
umap_results = umap.UMAP(n_neighbors=5,
                      min_dist=0.3,
                      metric='correlation').fit_transform(X_std)

# %%
plt.figure(figsize=(10, 10))

plt.scatter(umap_results[:, 0], umap_results[:, 1], alpha=.5, c=pd.Series(clusters));
